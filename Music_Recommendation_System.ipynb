# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import missingno as ms
# %matplotlib inline

# %%
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 2000)

# %%
echonest = pd.read_csv('members.csv')
echonest
# Out:
#                                                msno  city    bd  gender  \
# 0      XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=   1.0   0.0     NaN
# 1      UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=   1.0   0.0     NaN
# 2      D8nEhsIOBSoE6VthTaqDX8U6lqjJ7dLdr72mOyLya2A=   1.0   0.0     NaN
# 3      mCuD+tZ1hERA/o5GPqk38e041J8ZsBaLcu7nGoIIvhI=   1.0   0.0     NaN
# 4      q4HRBfVSssAFS9iRfxWrohxuk9kCYMKjHOEagUMV6rQ=   1.0   0.0     NaN
# ...                                             ...   ...   ...     ...
# 28810  U6Xn5KtGT6jWDlmqbJaovVFaoLnRS4Wc1FAPezZByQ8=  22.0  49.0  female
# 28811  4jxW6xtV4vSXYVXteKH+TKTh8/7Dw0IJ+i9SOegXcyg=   1.0   0.0     NaN
# 28812  4VqvqCcJaeT1Y87qqu6ArwEP4tM27e4Wj0SgdHjRW+c=   5.0  20.0  female
# 28813  r9YwE4z5Hlg1Q2PAx+1VIfqYrlPFuxgRyfNYv1c0YaI=   1.0   0.0     NaN
# 28814                  xiGNGEAhnp0epTh13Ysg8viyxnJd   NaN   NaN     NaN
#
#        registered_via  registration_init_time  expiration_date
# ...

# %%
ms.matrix(echonest)

# %%
echonest.tail(15)
# Out:
#                                                msno  city    bd  gender  \
# 28800  9PC/7uDwPWd9ilLO99B3HQzweMolRLugHG4kPeLO3iE=   1.0  17.0    male
# 28801  VefOCtAsmXrPQEOjzZgyxHG71lqNxAXh7w7wI88FO6I=   1.0   0.0     NaN
# 28802  r/ycXcarizwGR1WbmT96aTHQyBroJqHZ1YtBiK+KXGI=  13.0  23.0  female
# 28803  G+5Fjgwur0wIsOkpMByiCdvHa5LsWKMl5Q01GjQwFLg=   6.0  78.0    male
# 28804  8GFLkuYjfnRZpuLX7GxD+jMidzgkYajAgFGPW3g6BBI=   1.0   0.0     NaN
# 28805  Wwuo9APyeiMNBE8Qzif4zUUBp4djZJPPpCn1L+YyKVA=  11.0  25.0    male
# 28806  JTk6phkI3zqZxpeunImhXgAj6qZG8KziVVejLqUMTBI=  13.0  22.0    male
# 28807  miV73WTMJmaXAHbaxdzV8RCaAXHu0GgUa0q0QHjKfPo=   1.0   0.0     NaN
# 28808  1kZuvo9awEQZqnYVvaM2qedJoYkMNVK2XJJ77xAACYs=   1.0   0.0     NaN
# 28809  o/9oiyTRRIhpQw6DqKUuasmBsKWIL7WCYErEKOP147Y=  15.0  34.0  female
# 28810  U6Xn5KtGT6jWDlmqbJaovVFaoLnRS4Wc1FAPezZByQ8=  22.0  49.0  female
# 28811  4jxW6xtV4vSXYVXteKH+TKTh8/7Dw0IJ+i9SOegXcyg=   1.0   0.0     NaN
# ...

# %%
ms.matrix(echonest.iloc[:, 0:15])

# %%
echonest.head(10)
# Out:
#                                            msno  city    bd  gender  \
# 0  XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=   1.0   0.0     NaN
# 1  UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=   1.0   0.0     NaN
# 2  D8nEhsIOBSoE6VthTaqDX8U6lqjJ7dLdr72mOyLya2A=   1.0   0.0     NaN
# 3  mCuD+tZ1hERA/o5GPqk38e041J8ZsBaLcu7nGoIIvhI=   1.0   0.0     NaN
# 4  q4HRBfVSssAFS9iRfxWrohxuk9kCYMKjHOEagUMV6rQ=   1.0   0.0     NaN
# 5  zgPOEyUn5a/Fvuzb3m69ajzxjkbblVtObglW89FzLdo=  13.0  43.0  female
# 6  Sw9AT8QoR4wWiNUqHZUH6g5ahzGUx4lo1g+Y3xE2f2M=   1.0   0.0     NaN
# 7  pg6bT2XZkSP1TDBy4qn3HBPY/HffKQ/bg8WIISQYBSY=   1.0   0.0     NaN
# 8  kfk1AdTNH2dNqF5LzIs4e0vwGPejw2jrnFjJlcYnEgk=   1.0   0.0     NaN
# 9  tscijwx4dbEp0NXGl+iFtHJ8zrj+TkcMrduOQk9t+gE=   1.0   0.0     NaN
#
#    registered_via  registration_init_time  expiration_date
# 0             7.0              20110820.0       20170920.0
# 1             7.0              20150628.0       20170622.0
# ...

# %%
echonest.iloc[0, 0]
# Out:
# 'XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw='

# %%
echonest.iloc[1, 0]
# Out:
# 'UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM='

# %%
echonest.iloc[0, 0] = echonest.iloc[1, 0]

# %%
echonest.head()
# Out:
#                                            msno  city   bd gender  \
# 0  UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=   1.0  0.0    NaN
# 1  UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=   1.0  0.0    NaN
# 2  D8nEhsIOBSoE6VthTaqDX8U6lqjJ7dLdr72mOyLya2A=   1.0  0.0    NaN
# 3  mCuD+tZ1hERA/o5GPqk38e041J8ZsBaLcu7nGoIIvhI=   1.0  0.0    NaN
# 4  q4HRBfVSssAFS9iRfxWrohxuk9kCYMKjHOEagUMV6rQ=   1.0  0.0    NaN
#
#    registered_via  registration_init_time  expiration_date
# 0             7.0              20110820.0       20170920.0
# 1             7.0              20150628.0       20170622.0
# 2             4.0              20160411.0       20170712.0
# 3             9.0              20150906.0       20150907.0
# 4             4.0              20170126.0       20170613.0

# %%
def convert_to_float(df, columns):
    for i in columns:
        df[i] = df[i].astype('float')
    return df

# %%
echonest.shape
# Out:
# (28815, 7)

# %%
# Replace NA
for i in echonest.select_dtypes(include=['object']).columns:
    echonest[i][echonest[i].isnull()] = 'unknown'
df = echonest.fillna(value=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Dates to categoty
df['registration_init_time'] = df['registration_init_time'].astype('category')
df['expiration_date'] = df['expiration_date'].astype('category')

# %%
# Object data to category
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].astype('category')
    
# Encoding categorical features
for col in df.select_dtypes(include=['category']).columns:
    df[col] = df[col].cat.codes

# %%
df.corr()
# Out:
#                             msno      city        bd    gender  \
# msno                    1.000000  0.010875  0.000537 -0.006331
# city                    0.010875  1.000000  0.562634 -0.622020
# bd                      0.000537  0.562634  1.000000 -0.708833
# gender                 -0.006331 -0.622020 -0.708833  1.000000
# registered_via         -0.001701  0.231130  0.234963 -0.202796
# registration_init_time -0.003069 -0.432708 -0.470503  0.467232
# expiration_date         0.005761  0.272009  0.230292 -0.224044
#
#                         registered_via  registration_init_time  \
# msno                         -0.001701               -0.003069
# city                          0.231130               -0.432708
# bd                            0.234963               -0.470503
# gender                       -0.202796                0.467232
# registered_via                1.000000               -0.568157
# registration_init_time       -0.568157                1.000000
# ...

# %%
plt.figure(figsize=[7,5])
sns.heatmap(df.corr())
plt.show()
